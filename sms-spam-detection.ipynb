# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
# Steps:
# Data Cleaning
# Exploratory Data Analysis
# Text Preprocessing
# Model Building
# Evaluation
# Improvements
# Website
# Deployment

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 columns
df.drop(columns=['Unnamed: 2','Unnamed: 3', 'Unnamed: 4'], inplace = True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 1524  ham                      Hi:)cts employee how are you?
# 3598  ham             Then wat r u doing now? Busy wif work?
# 3600  ham                       Jay told me already, will do
# 2151  ham  I surely dont forgot to come:)i will always be...
# 2650  ham  Do you like shaking your booty on the dance fl...

# %%
# rename the cols
df.rename(columns = {'v1': 'target', 'v2': 'text'}, inplace = True)
df.sample(5)
# Out:
#      target                                               text
# 4327   spam  Congrats! 2 mobile 3G Videophones R yours. cal...
# 4366    ham  I like dis sweater fr mango but no more my siz...
# 1750    ham                         Got it..mail panren paru..
# 1395    ham  Thats cool! I am a gentleman and will treat yo...
# 3575    ham  The sign of maturity is not when we start sayi...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# checking missing values

df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# checking for duplicate vals

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep = 'first')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels = ['ham', 'spam'], autopct = '%0.2f')
plt.show()

# %%
# Issues: 
# 1. Data is imbalanced

# %%
import nltk
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sami\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\sami\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\sami\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sami\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\sami\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\sami\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sami\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)
# Out:
# C:\Users\Sami\AppData\Local\Temp\ipykernel_4120\253964734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# num of words
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\Sami\AppData\Local\Temp\ipykernel_4120\192676766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\Sami\AppData\Local\Temp\ipykernel_4120\589552786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.453279       1.947185
# std         58.236293    13.324793       1.362406
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# Ham
df[df['target'] == 0][['num_characters','num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.120903       1.799601
# std         56.358207    13.493725       1.278465
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# Spam
df[df['target'] == 1][['num_characters','num_words', 'num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.967841
# std         30.137753    7.008418       1.483201
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       8.000000

# %%
import seaborn as sns

# %% [markdown]
# # Num of Characters

# %%
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_characters']) # ham
sns.histplot(df[df['target'] == 1]['num_characters'], color = 'red') # spam
# Out:
# <AxesSubplot:xlabel='num_characters', ylabel='Count'>

# %% [markdown]
# # Num of Words

# %%
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_words']) # ham
sns.histplot(df[df['target'] == 1]['num_words'], color = 'red') # spam
# Out:
# <AxesSubplot:xlabel='num_words', ylabel='Count'>

# %% [markdown]
# # Num of Sentences

# %%
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_sentences']) # ham
sns.histplot(df[df['target'] == 1]['num_words'], color = 'red') # spam
# Out:
# <AxesSubplot:xlabel='num_sentences', ylabel='Count'>

# %% [markdown]
# # Data relationship

# %%
sns.pairplot(df, hue='target')

# %% [markdown]
# # Corelation-Coefficient

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Text Preprocessing

# %%
# Lower Case
# Tokenization
# Removing Special characters
# Removing stop words
# Stemming

# %%
nltk.download('stopwords')
import string
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()


def transform_text(text):
    text = text.lower();
    text = nltk.word_tokenize(text)
    result = []
    for i in text:
        if i.isalnum():
            result.append(i)
            
    text = result[:]
    result.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            result.append(i)
    text = result[:]
    result.clear()
    
    for i in text:
        result.append(ps.stem(i))
        
    return " ".join(result)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sami\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
from wordcloud import WordCloud

wc = WordCloud(width = 500, height = 500, min_font_size = 10, background_color = 'white')
# Out:
# Requirement already satisfied: wordcloud in c:\users\sami\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in c:\users\sami\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sami\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\sami\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sami\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\sami\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep = " "))

# %% [markdown]
# # SPAM MESSAGE WORD CLOUD

# %%
plt.figure(figsize = (15,6))
plt.imshow(spam_wc)

# %% [markdown]
# # HAM TEXT WORD CLOUD

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize = (15,6))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for words in msg.split():
        spam_corpus.append(words)

# %% [markdown]
# # 30 Most Common Spam Words

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0], pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# C:\Users\Sami\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for words in msg.split():
        ham_corpus.append(words)

# %% [markdown]
# # 30 Most Common Ham Words

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(ham_corpus).most_common(30))[0], pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# C:\Users\Sami\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Model Building

# %%
# text vectorization
# using bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features = 3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,Y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,Y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,Y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
import pickle
pickle.dump(tfidf, open('vectorizer.pk1','wb'))
pickle.dump(mnb, open('model.pkl', 'wb'))
